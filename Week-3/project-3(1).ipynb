# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


email_address = input("Email Address: ")
age = int(input("Age: ").strip().lower())


def Translation():
    img = cv.imread('img/sst.jpeg',0)
    rows, cols = img.shape
    
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(img)
    
    M = np.float32([[1,0,100],[0,1,50]])
    transl = cv.warpAffine(img, M, (cols,rows))
    
    plt.subplot(1,2,2)
    plt.title("Translated Image")
    plt.imshow(transl)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
        
    
def Reflection():
  
    img = cv.imread("img/sst.jpeg",0)
    
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(img)
    
    rows, cols = img.shape
    M = np.float32([[1,0,0],[0,-1,rows],[0,0,1]])
    reflected_img = cv.warpPerspective(img, M, (int(cols), int(rows)))
    
    plt.subplot(1,2,2)
    plt.title("Reflected Image")
    plt.imshow(reflected_img)
    
    cv.imwrite("reflection_out", reflected_img)
    cv.waitKey(0)
    cv.destrouAllWindows()

def Rotation():

    img = cv.imread("img/sst.jpeg",0)
    rows, cols = img.shape
    
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(img)
    
    img_rotation = cv.warpAffine(img, cv.getRotationMatrix2D((cols/2,rows/2),30,0.6), (cols,rows))
    
    plt.subplot(1,2,2)
    plt.title("Rotated Image")
    plt.imshow(img_rotation)
    
    cv.imshow('img', img_rotation)
    cv.imwrite("img/rotation_out.jpeg", img_rotation)
    cv.waitKey(0)
    cv.destroyAllWindows()

def Cropped():

    img = cv.imread("img/sst.jpeg",0)
    rows, cols = img.shape
    
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(img)
    
    cropped_img = img[150:500,200:500]
    
    plt.subplot(1,2,2)
    plt.title("Cropped Image")
    plt.imshow(cropped_img)
    
    cv.imwrite("img/cropped_out.jpeg", cropped_img)
    cv.waitKey(0)
    cv.destroyAllWindows()

def X():

    img = cv.imread("img/sst.jpeg",0)
    rows, cols = img.shape
    
    plt.subplot(1,2,1)
    plt.title("Original")
    plt.imshow(img)
    
    M = np.float32([[1,0.5,0],[0,1,0],[0,0,1]])
    sheared_img = cv.warpPerspective(img, M, (int(cols*1.5),int(rows*1.5)))
    
    plt.subplot(1,2,2)
    plt.title("shearead Image")
    plt.imshow(sheared_img)
    
    cv.imshow("img", sheared_img)
    cv.waitKey(0)
    cv.destroyAllWindows()

def Y():
img = cv.imread("img/sst.jpeg",0)
rows, cols = img.shape

plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(img)

M = np.float32([[1,0,0],[0.5,1,0],[0,0,1]])
sheared_img = cv.warpPerspective(img, M, (int(cols*1.5),int(rows*1.5)))

plt.subplot(1,2,2)
plt.title("shearead Image Y-Axis")
plt.imshow(sheared_img)

cv.imshow("img", sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

   

def Blur ():
    image = cv.imread("img/sst.jpeg",0)
    
    cv.imshow("original image", image)
    cv.waitKey(0)
    
    Gaussian = cv.GaussianBlur(image, (7,7),0)
    cv.imshow("Gaussian Blurring", Gaussian)
    cv.waitKey(0)
    
    median = cv.medianBlur(image,5)
    cv.imshow("Median Blurring", median)
    cv.waitKey(0)
    
    
    bilateral = cv.bilateralFilter(image,9,75,75)
    cv.imshow("Bilateral Blurring", bilateral)
    cv.waitKey(0)
    cv.destroyAllWindows()

if age> 18:
     print("Which catgory of images do you want to see : ")
     print("1: Contemporary")
     print("2: Modern ")
     print("3: Traditonal ")

            
    catgeory = input("").strip().lower()
    match option:
        case "1":
            print("Which image do you want to see : ")
            print("Image1")
            print("Image2")
            print("Image3")

            
            image = input("").strip().lower()
            match image:
                case "1":
                    path = "img/contem1.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "2":
                    path = "img/contem2.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "3":
                    path = "img/contem3.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                    
      
        case "2":
            print("Which image do you want to see : ")
            print("Image1")
            print("Image2")
            print("Image3")

            
            image = input("").strip().lower()
            match image:
                case "1":
                    path = "img/modern1.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "2":
                    path = "img/modern2.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "3":
                    path = "img/modern3.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                    

         
        case "3":
            print("Which image do you want to see : ")
            print("Image1")
            print("Image2")
            print("Image3")

            
            image = input("").strip().lower()
            match image:
                case "1":
                    path = "img/trad1.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "2":
                    path = "img/trad2.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                case "3":
                    path = "img/trad3.jpeg"
                    img = cv2.imread(path)
                    window_name = "Display Image"
                    cv2.imshow(window_name, img)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
                    
                    print("Which transformation do you want to see on this image : ")
                    print("Translation")
                    print("Reflection")
                    print("Image Rotation")
                    print("Image Cropping")
                    print("Shared Image in X-Axis")
                    print("Shared Image in Y-Axis")
                    print("Image Blurring")

                    Transformation = input("").strip().lower()

                    match Transformation:
                        case "1":
                            Translation()
                        case "2":
                            Reflection()
                        case "3":
                            Rotation()
                        case "4":
                            Cropped()
                        case "5":
                            X()
                        case "6":
                            Y()
                        case "7":
                            Blur()
                    
            
            
    
else:
    print("You must be above 18 years old to access images")
